# %% [markdown]
# <a href="https://colab.research.google.com/github/yashgeed-AI-DS/Pandas/blob/main/Pandas_Class5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as pd
data = {
    'Product':['Pen','Notebook','Pencil','Marker','Eraser','Sharpner'],
    'Price' :[10,50,5,30,8,12],
    'Stock' : [100,60,200,80,150,120],
    'Rating' :[4.5,4.7,4.2,4.8,4.3,4.4]
}
df = pd.DataFrame(data)
df
#1 sort by a single column _> price,ascending
print(df.sort_values(by = 'Price'))
#2. sort by a single column -> Price,Descending
print(df.sort_values(by = 'Rating',ascending = False))
#3.sort by multiple column -> Price,Stock
print(df.sort_values(by = ['Price','Stock']))
#4.Sort index -> in descending order
print(df.sort_index(ascending = False))
# Out:
#     Product  Price  Stock  Rating
# 2    Pencil      5    200     4.2
# 4    Eraser      8    150     4.3
# 0       Pen     10    100     4.5
# 5  Sharpner     12    120     4.4
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
#     Product  Price  Stock  Rating
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5
# 5  Sharpner     12    120     4.4
# 4    Eraser      8    150     4.3
# 2    Pencil      5    200     4.2
#     Product  Price  Stock  Rating
# 2    Pencil      5    200     4.2
# 4    Eraser      8    150     4.3
# 0       Pen     10    100     4.5
# 5  Sharpner     12    120     4.4
# 3    Marker     30     80     4.8
# 1  Notebook     50     60     4.7
#     Product  Price  Stock  Rating
# 5  Sharpner     12    120     4.4
# 4    Eraser      8    150     4.3
# 3    Marker     30     80     4.8
# 2    Pencil      5    200     4.2
# 1  Notebook     50     60     4.7
# 0       Pen     10    100     4.5

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
print(df)
#1.Mean of numeric columns only
df.mean(numeric_only = True)
#2 Median
df.median(numeric_only = True)
#3 .Mode
print(df.mode())
#4.Standard Deviation
print(df.std(numeric_only = True))
#5.Complete statistical value of column
print(df.describe())
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 1  Notebook     50     60     4.7
# 2    Pencil      5    200     4.2
# 3    Marker     30     80     4.8
# 4    Eraser      8    150     4.3
# 5  Sharpner     12    120     4.4
#     Product  Price  Stock  Rating
# 0    Eraser      5     60     4.2
# 1    Marker      8     80     4.3
# 2  Notebook     10    100     4.4
# 3       Pen     12    120     4.5
# 4    Pencil     30    150     4.7
# 5  Sharpner     50    200     4.8
# Price     17.486185
# Stock     50.760877
# Rating     0.231661
# dtype: float64
#            Price       Stock    Rating
# count   6.000000    6.000000  6.000000
# mean   19.166667  118.333333  4.483333
# std    17.486185   50.760877  0.231661
# min     5.000000   60.000000  4.200000
# 25%     8.500000   85.000000  4.325000
# 50%    11.000000  110.000000  4.450000
# 75%    25.500000  142.500000  4.650000
# max    50.000000  200.000000  4.800000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
print(df)
#1.Count how many times each product appears
print(df['Product'].value_counts())
#2.Show percentage instead of counts
print(df['Product'].value_counts(normalize = True))
#3.count values for Rating
print(df['Rating'].value_counts())
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.5
# 1  Notebook     50     60     4.7
# 2    Pencil      5    200     4.2
# 3    Marker     30     80     4.8
# 4    Eraser      8    150     4.3
# 5  Sharpner     12    120     4.4
# Product
# Pen         1
# Notebook    1
# Pencil      1
# Marker      1
# Eraser      1
# Sharpner    1
# Name: count, dtype: int64
# Product
# Pen         0.166667
# Notebook    0.166667
# Pencil      0.166667
# Marker      0.166667
# Eraser      0.166667
# Sharpner    0.166667
# Name: proportion, dtype: float64
# Rating
# 4.5    1
# 4.7    1
# 4.2    1
# 4.8    1
# 4.3    1
# 4.4    1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
#1 Correlation between all numeric column
# -ve correlation ->  once increases 2nd decreases
# +ve correlation -> one increases other increases
print(df.corr(numeric_only = True))
#2.covariance between all numeric column
print(df.cov(numeric_only = True))
#3.Correlation between 2 specific column
print(df['Price'].corr(df['Stock']))
# Out:
#            Price     Stock    Rating
# Price   1.000000 -0.804028  0.820402
# Stock  -0.804028  1.000000 -0.921257
# Rating  0.820402 -0.921257  1.000000
#              Price        Stock     Rating
# Price   305.766667  -713.666667   3.323333
# Stock  -713.666667  2576.666667 -10.833333
# Rating    3.323333   -10.833333   0.053667
# -0.8040280933316356

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height
import pandas as pd
data = pd.DataFrame({
    'Name': ['Yash','Ram','Nikhil','Alok'],
    'Age':[19,20,21,22],
    'Score':[99,87,76,54],
    'Height':[175,154,167,188],
})
print(data)
# 2. Sort the data by Score (descending)
print(data.sort_values(by = 'Score',ascending = False))
# 3. Get mean, median, mode, and std of numeric columns
print(data.mean(numeric_only = True))
print(data.median(numeric_only = True))
print(data.mode())
print(data.std(numeric_only = True))
# 4. Use value_counts on Name or any categorical column
print(data['Name'].value_counts())

# 5. Compute corr() and cov() for all numeric columns
print(data.corr(numeric_only = True))
print(data.cov(numeric_only = True))
# Out:
#      Name  Age  Score  Height
# 0    Yash   19     99     175
# 1     Ram   20     87     154
# 2  Nikhil   21     76     167
# 3    Alok   22     54     188
#      Name  Age  Score  Height
# 0    Yash   19     99     175
# 1     Ram   20     87     154
# 2  Nikhil   21     76     167
# 3    Alok   22     54     188
# Age        20.5
# Score      79.0
# Height    171.0
# dtype: float64
# Age        20.5
# Score      81.5
# Height    171.0
# dtype: float64
#      Name  Age  Score  Height
# 0    Alok   19     54     154
# 1  Nikhil   20     76     167
# 2     Ram   21     87     175
# 3    Yash   22     99     188
# Age        1.290994
# Score     19.131126
# Height    14.259500
# dtype: float64
# Name
# Yash      1
# Ram       1
# Nikhil    1
# Alok      1
# Name: count, dtype: int64
#              Age     Score    Height
# Age     1.000000 -0.985228  0.470786
# Score  -0.985228  1.000000 -0.573069
# Height  0.470786 -0.573069  1.000000
#               Age       Score      Height
# Age      1.666667  -24.333333    8.666667
# Score  -24.333333  366.000000 -156.333333
# Height   8.666667 -156.333333  203.333333
# -0.9852278683843477

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
