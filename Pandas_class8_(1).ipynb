# %% [markdown]
# <a href="https://colab.research.google.com/github/yashgeed-AI-DS/Pandas/blob/main/Pandas_class8_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 8: Working with Time Series
# Welcome to **Class 8** of our Pandas series. Today we’ll learn how to handle and analyze time series data.

# %% [markdown]
# ## 1. Converting Columns to Datetime (`pd.to_datetime`)
# - Use `pd.to_datetime()` to convert strings or numbers into datetime objects.
# - Once converted, Pandas recognizes them as dates, enabling powerful operations.

# %%
import pandas as pd

# 1. Create the dataset
data = {
    "OrderID": [1001, 1002, 1003, 1004, 1005],
    "OrderDate": ["2024-01-05", "2024/01/12", "15-01-2024", "2024-01-20", "20240125"],
    "Customer": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Amount": [250, 400, 150, 300, 500]
}
df =pd.DataFrame(data)
print(df)
df.info()

# mixed formet of the  Data
df['OrderDate']=pd.to_datetime(df['OrderDate'],format='mixed',errors="coerce")
print(df)
# Out:
#    OrderID   OrderDate Customer  Amount
# 0     1001  2024-01-05    Alice     250
# 1     1002  2024/01/12      Bob     400
# 2     1003  15-01-2024  Charlie     150
# 3     1004  2024-01-20    David     300
# 4     1005    20240125     Emma     500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderID    5 non-null      int64
#  1   OrderDate  5 non-null      object
#  2   Customer   5 non-null      object
#  3   Amount     5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#    OrderID  OrderDate Customer  Amount
# 0     1001 2024-01-05    Alice     250
# 1     1002 2024-01-12      Bob     400
# 2     1003 2024-01-15  Charlie     150
# 3     1004 2024-01-20    David     300
# 4     1005 2024-01-25     Emma     500

# %%
# Spesific formet of the  Data
df["OrderDate"]=pd.to_datetime(df["OrderDate"],errors='corece',format='mixed').dt.strftime('%d-%m-%y')
print(df)
df.info()
# Out:
#    OrderID OrderDate Customer  Amount
# 0     1001  05-01-24    Alice     250
# 1     1002  12-01-24      Bob     400
# 2     1003  15-01-24  Charlie     150
# 3     1004  20-01-24    David     300
# 4     1005  25-01-24     Emma     500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderID    5 non-null      int64
#  1   OrderDate  5 non-null      object
#  2   Customer   5 non-null      object
#  3   Amount     5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# ## 2. Setting DateTime Index & Resampling
# - Set a datetime column as the index with `set_index()`.
# - Resample time series using `resample('M').mean()` or other rules ('D', 'W', 'Y').
# - Useful for aggregating data by time periods.

# %%
import pandas as pd

# 1. Create the dataset
data = {
    "OrderID": [1001, 1002, 1003, 1004, 1005],
    "OrderDate": ["2024-01-05", "2024/01/12", "15-01-2024", "2024-01-20", "20240125"],
    "Customer": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Amount": [250, 400, 150, 300, 500]
}
df =pd.DataFrame(data)

print(df)
df.info()

# mixed formet of the  Data
df['OrderDate']=pd.to_datetime(df['OrderDate'],format='mixed',errors="coerce")
print(df)

#step1:- Orderdate set as index
df_idx = df.set_index('OrderDate')
df_idx
#Step2:- We will resample complete data
#
monthly_amount=df_idx.resample('M')['Amount'].sum()
print(monthly_amount)

Year_amount=df_idx.resample('Y')['Amount'].sum()
print(Year_amount)

Week_amount=df_idx.resample('W')['Amount'].sum()
print(Week_amount)
# Out:
#    OrderID   OrderDate Customer  Amount
# 0     1001  2024-01-05    Alice     250
# 1     1002  2024/01/12      Bob     400
# 2     1003  15-01-2024  Charlie     150
# 3     1004  2024-01-20    David     300
# 4     1005    20240125     Emma     500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderID    5 non-null      int64
#  1   OrderDate  5 non-null      object
#  2   Customer   5 non-null      object
#  3   Amount     5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#    OrderID  OrderDate Customer  Amount
# 0     1001 2024-01-05    Alice     250
# 1     1002 2024-01-12      Bob     400
# 2     1003 2024-01-15  Charlie     150
# 3     1004 2024-01-20    David     300
# 4     1005 2024-01-25     Emma     500
# OrderDate
# 2024-01-31    1600
# Freq: ME, Name: Amount, dtype: int64
# OrderDate
# 2024-12-31    1600
# Freq: YE-DEC, Name: Amount, dtype: int64
# OrderDate
# 2024-01-07    250
# 2024-01-14    400
# 2024-01-21    450
# 2024-01-28    500
# Freq: W-SUN, Name: Amount, dtype: int64
# /tmp/ipykernel_2949/1764123260.py:24: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_amount=df_idx.resample('M')['Amount'].sum()
# /tmp/ipykernel_2949/1764123260.py:27: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   Year_amount=df_idx.resample('Y')['Amount'].sum()

# %% [markdown]
# ## mini-project
#
# Converting columns to datetime (pd.to_datetime)
#
# Setting a DateTime index & resampling

# %%
import pandas as pd

# 1️⃣ Create a dataset of website visits (string dates + visit counts)
data = {
    "VisitDate": [
        "2026-01-01", "2026-01-03", "2026-01-15", "2026-02-04",
        "2026-02-14", "2026-02-28", "2026-03-05", "2026-03-22"
    ],
    "Visits": [120, 150, 90, 210, 180, 250, 300, 310]
}
df = pd.DataFrame(data)


# 2️⃣ Convert VisitDate to datetime
df["VisitDate"] = pd.to_datetime(df["VisitDate"])


# 3️⃣ Set VisitDate as the index
df.set_index("VisitDate", inplace=True)


# 4️⃣ Resample to get total visitors per month
# 'ME' stands for Month End frequency
monthly_totals = df.resample("ME").sum()
print("--- Monthly Totals ---")
print(monthly_totals)


# 5️⃣ Resample to get average visitors per week
# 'W' stands for Weekly frequency
weekly_averages = df.resample("W").mean()
print("\n--- Weekly Averages ---")
print(weekly_averages)
# Out:
# --- Monthly Totals ---
#             Visits
# VisitDate
# 2026-01-31     360
# 2026-02-28     640
# 2026-03-31     610
#
# --- Weekly Averages ---
#             Visits
# VisitDate
# 2026-01-04   135.0
# 2026-01-11     NaN
# 2026-01-18    90.0
# 2026-01-25     NaN
# 2026-02-01     NaN
# 2026-02-08   210.0
# 2026-02-15   180.0
# 2026-02-22     NaN
# 2026-03-01   250.0
# 2026-03-08   300.0
# 2026-03-15     NaN
# 2026-03-22   310.0

# %% [markdown]
# ---
# ## Summary
# - Converted columns to datetime with `pd.to_datetime`.
# - Set DateTime index and resampled data.
# - Performed date-based filtering and slicing.
# - Applied rolling and expanding window calculations.
