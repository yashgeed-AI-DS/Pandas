# %% [markdown]
# <a href="https://colab.research.google.com/github/yashgeed-AI-DS/Pandas/blob/main/pandas_class6_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Class 6 Assignment
#
# ## Level: Basic to Intermediate
#
# ### Instructions
# - Solve all questions using Pandas.
# - Write code in the blank code cell below each question.
# - Print the required output.

# %% [markdown]
# # Q1. Display Unique Values
#
# ## Problem Statement
# Create a DataFrame with a City column and display all unique cities.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# ['Bhopal' 'Indore' 'Delhi']
# ```

# %%
import pandas as pd
data = pd.DataFrame({
    'City':["Bhopal", "Indore", "Bhopal", "Delhi"]
})
print(data['City'].unique())
# Out:
# ['Bhopal' 'Indore' 'Delhi']

# %% [markdown]
# # Q2. Count Unique Values
#
# ## Problem Statement
# Find the number of unique cities in a DataFrame.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# 3
# ```

# %%
data = pd.DataFrame({
    'City':["Bhopal", "Indore", "Bhopal", "Delhi"]
})
print(data['City'].nunique())
# Out:
# 3

# %% [markdown]
# # Q3. Value Counts
#
# ## Problem Statement
# Count occurrences of each city.
#
# ## Sample Input
# ```python
# City = ["Bhopal", "Indore", "Bhopal", "Delhi"]
# ```
#
# ## Sample Output
# ```python
# Bhopal    2
# Indore    1
# Delhi     1
# ```

# %%
print(data['City'].value_counts())
# Out:
# City
# Bhopal    2
# Indore    1
# Delhi     1
# Name: count, dtype: int64

# %% [markdown]
# # Q4. Group By City
#
# ## Problem Statement
# Find average marks city-wise using groupby().
#
# ## Sample Input
# ```python
# City   Marks
# Bhopal 80
# Bhopal 90
# Delhi  70
# ```
#
# ## Sample Output
# ```python
# Bhopal 85
# Delhi  70
# ```

# %%
data = pd.DataFrame({
    'City':['Bhopal','Bhopal','Delhi'],
    'Marks':[80,90,70]
})
print(data.groupby('City')['Marks'].mean())
# Out:
# City
# Bhopal    85.0
# Delhi     70.0
# Name: Marks, dtype: float64

# %% [markdown]
# # Q5. Sort Values
#
# ## Problem Statement
# Sort students by Marks in ascending order.
#
# ## Sample Output
# ```python
# Sorted DataFrame
# ```

# %%
data = pd.DataFrame({
    'Name':['A','B','C'],
    'Marks':[80,90,70]
})
print(data.sort_values('Marks'))
# Out:
#   Name  Marks
# 2    C     70
# 0    A     80
# 1    B     90

# %% [markdown]
# # Q6. Sort Values Descending
#
# ## Problem Statement
# Sort students by Marks in descending order.
#
# ## Sample Output
# ```python
# Sorted DataFrame
# ```

# %%
print(data.sort_values(by = 'Marks',ascending = False))
# Out:
#   Name  Marks
# 1    B     90
# 0    A     80
# 2    C     70

# %% [markdown]
# # Q7. Filter Records
#
# ## Problem Statement
# Display students having marks greater than 75.
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
print(data[data['Marks']>75])
# Out:
#   Name  Marks
# 0    A     80
# 1    B     90

# %% [markdown]
# # Q8. Multiple Conditions
#
# ## Problem Statement
# Display students whose marks are greater than 70 and age is greater than 20.
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
data = pd.DataFrame({
    'Name':['A','B','C'],
    'Marks':[80,90,70],
    'Age':[22,21,20]
})

print(data[data['Marks']>70])
print(data[data['Age']>20])
# Out:
#   Name  Marks  Age
# 0    A     80   22
# 1    B     90   21
#   Name  Marks  Age
# 0    A     80   22
# 1    B     90   21

# %% [markdown]
# # Q9. Group By Department
#
# ## Problem Statement
# Create Employee and Department data and find total salary department-wise.
#
# ## Sample Output
# ```python
# HR       50000
# IT      120000
# ```

# %%
data = pd.DataFrame({
    'Name':['A','B','C'],
    'Salary':[10000,20000,30000],
    'Department':['HR','IT','IT']
})
print(data.groupby('Department')['Salary'].sum())
# Out:
# Department
# HR    10000
# IT    50000
# Name: Salary, dtype: int64

# %% [markdown]
# # Q10. Complete Practice Question
#
# ## Problem Statement
# Create a DataFrame containing:
# - Name
# - Age
# - City
# - Marks
#
# Perform:
# 1. Show unique cities
# 2. Count city frequency
# 3. Filter marks > 80
# 4. Sort by marks
#
# ## Sample Output
# ```python
# Required Results
# ```

# %%
data = pd.DataFrame({
    'Name':['Alice','Bob','Kevin','David'],
    'Age':[29,25,30,32],
    'City':['Melbourne','Barbados','Melbourne','Brisbane'],
    'Marks':[79,81,54,90]
})
print(data['City'].unique())
print(data['City'].value_counts())
print(data[data['Marks']>80])
print(data.sort_values(by = 'Marks'))
# Out:
# ['Melbourne' 'Barbados' 'Brisbane']
# City
# Melbourne    2
# Barbados     1
# Brisbane     1
# Name: count, dtype: int64
#     Name  Age      City  Marks
# 1    Bob   25  Barbados     81
# 3  David   32  Brisbane     90
#     Name  Age       City  Marks
# 2  Kevin   30  Melbourne     54
# 0  Alice   29  Melbourne     79
# 1    Bob   25   Barbados     81
# 3  David   32   Brisbane     90
