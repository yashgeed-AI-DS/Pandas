# %% [markdown]
# <a href="https://colab.research.google.com/github/yashgeed-AI-DS/Pandas/blob/main/Pandas_Class7_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Class 7 Assignment
#
#
# ### Topics Covered
# - Creating DataFrame
# - Selecting Columns
# - Filtering
# - Sorting
# - groupby()
# - value_counts()
# - Creating New Columns
# - drop_duplicates()
# - fillna()
#
# ### Instructions
# - Create the DataFrame whenever required.
# - Solve all questions using Pandas.
# - Write your solution in the blank code cell after each question.

# %% [markdown]
# # Q1. Create a Student DataFrame
#
# ## Problem Statement
# Create the following DataFrame using a Python dictionary.
#
# | Name | Age | City | Marks |
# |------|----:|------|------:|
# | Aman | 21 | Bhopal | 85 |
# | Rahul | 22 | Indore | 72 |
# | Neha | 20 | Delhi | 91 |
# | Priya | 23 | Bhopal | 68 |
# | Ravi | 21 | Indore | 95 |
#
# ## Sample Input
# ```python
# data = {
# "Name":["Aman","Rahul","Neha","Priya","Ravi"],
# "Age":[21,22,20,23,21],
# "City":["Bhopal","Indore","Delhi","Bhopal","Indore"],
# "Marks":[85,72,91,68,95]
# }
# ```
#
# ## Sample Output
# ```python
# Display the complete DataFrame.
# ```

# %%
import pandas as pd
data = pd.DataFrame({
"Name":["Aman","Rahul","Neha","Priya","Ravi"],
"Age":[21,22,20,23,21],
"City":["Bhopal","Indore","Delhi","Bhopal","Indore"],
"Marks":[85,72,91,68,95]
})
print(data)
# Out:
#     Name  Age    City  Marks
# 0   Aman   21  Bhopal     85
# 1  Rahul   22  Indore     72
# 2   Neha   20   Delhi     91
# 3  Priya   23  Bhopal     68
# 4   Ravi   21  Indore     95

# %% [markdown]
# # Q2. Display Selected Columns
#
# ## Problem Statement
# Using the DataFrame created in Question 1, display only the **Name** and **Marks** columns.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# Name and Marks columns only.
# ```

# %%
print(data[['Name','Marks']])
# Out:
#     Name  Marks
# 0   Aman     85
# 1  Rahul     72
# 2   Neha     91
# 3  Priya     68
# 4   Ravi     95

# %% [markdown]
# # Q3. Filter Students
#
# ## Problem Statement
# Display only those students whose **Marks are greater than 75**.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# Filtered rows.
# ```

# %%
data[(data['Marks']>75)]
# Out:
#    Name  Age    City  Marks
# 0  Aman   21  Bhopal     85
# 2  Neha   20   Delhi     91
# 4  Ravi   21  Indore     95

# %% [markdown]
# # Q4. Sort by Marks
#
# ## Problem Statement
# Sort the DataFrame by **Marks** in descending order.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# Sorted DataFrame.
# ```

# %%
data.sort_values(by = 'Marks',ascending = False)
# Out:
#     Name  Age    City  Marks
# 4   Ravi   21  Indore     95
# 2   Neha   20   Delhi     91
# 0   Aman   21  Bhopal     85
# 1  Rahul   22  Indore     72
# 3  Priya   23  Bhopal     68

# %% [markdown]
# # Q5. Average Marks by City
#
# ## Problem Statement
# Find the average Marks of each City using **groupby()**.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# Average marks city-wise.
# ```

# %%
data.groupby('City')['Marks'].mean()
# Out:
# City
# Bhopal    76.5
# Delhi     91.0
# Indore    83.5
# Name: Marks, dtype: float64

# %% [markdown]
# # Q6. Count Students by City
#
# ## Problem Statement
# Count the number of students in each City using **value_counts()**.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# City frequency.
# ```

# %%
data.value_counts('City')
# Out:
# City
# Bhopal    2
# Indore    2
# Delhi     1
# Name: count, dtype: int64

# %% [markdown]
# # Q7. Create Result Column
#
# ## Problem Statement
# Create a new column named **Result**. If Marks are **40 or more**, store **Pass**, otherwise **Fail**.
#
# ## Sample Input
# ```python
# Use the DataFrame from Q1
# ```
#
# ## Sample Output
# ```python
# Updated DataFrame with Result column.
# ```

# %%
data['Result'] = ['Pass' if marks >= 40 else 'Fail' for marks in data['Marks']]
print(data)
# Out:
#     Name  Age    City  Marks Result
# 0   Aman   21  Bhopal     85   Pass
# 1  Rahul   22  Indore     72   Pass
# 2   Neha   20   Delhi     91   Pass
# 3  Priya   23  Bhopal     68   Pass
# 4   Ravi   21  Indore     95   Pass

# %% [markdown]
# # Q8. Remove Duplicate Rows
#
# ## Problem Statement
# Create the following DataFrame:
#
# | Name | Age | City | Marks |
# |------|----:|------|------:|
# | Aman | 21 | Bhopal | 85 |
# | Rahul | 22 | Indore | 72 |
# | Aman | 21 | Bhopal | 85 |
# | Neha | 20 | Delhi | 91 |
#
# Remove duplicate rows using **drop_duplicates()**.
#
# ## Sample Input
# ```python
# Use the table above.
# ```
#
# ## Sample Output
# ```python
# Duplicate rows removed.
# ```

# %%
data.drop_duplicates()
# Out:
#     Name  Age    City  Marks
# 0   Aman   21  Bhopal     85
# 1  Rahul   22  Indore     72
# 2   Neha   20   Delhi     91
# 3  Priya   23  Bhopal     68
# 4   Ravi   21  Indore     95

# %% [markdown]
# # Q9. Fill Missing Values
#
# ## Problem Statement
# Create the following DataFrame:
#
# | Name | Marks |
# |------|------:|
# | Aman | 85 |
# | Rahul | NaN |
# | Neha | 91 |
# | Priya | NaN |
#
# Fill missing values in the **Marks** column with **0** using **fillna()**.
#
# ## Sample Input
# ```python
# Use the table above.
# ```
#
# ## Sample Output
# ```python
# Missing values replaced with 0.
# ```

# %%
data.fillna(0)
# Out:
#     Name  Age    City  Marks
# 0   Aman   21  Bhopal     85
# 1  Rahul   22  Indore     72
# 2   Neha   20   Delhi     91
# 3  Priya   23  Bhopal     68
# 4   Ravi   21  Indore     95

# %% [markdown]
# # Q10. Final Practice
#
# ## Problem Statement
# Create a DataFrame with the following data:
#
# | Name | City | Marks |
# |------|------|------:|
# | Aman | Bhopal | 85 |
# | Rahul | Indore | 72 |
# | Neha | Delhi | 91 |
# | Priya | Bhopal | 68 |
# | Ravi | Indore | 95 |
#
# Perform all of the following:
# 1. Display students with Marks > 80.
# 2. Sort the DataFrame by Marks.
# 3. Find the average Marks of each City.
#
# ## Sample Input
# ```python
# Use the table above.
# ```
#
# ## Sample Output
# ```python
# Required outputs displayed.
# ```

# %%
data[(data['Marks']>85)]
data.sort_values(by = 'Marks',ascending = False)
data.groupby('City')['Marks'].mean()
# Out:
# City
# Bhopal    76.5
# Delhi     91.0
# Indore    83.5
# Name: Marks, dtype: float64
